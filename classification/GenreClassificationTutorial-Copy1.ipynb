# %% [markdown]
# ### MULTICLASS CLASSIFICATION FOR METAL, CLASSICAL, BLUES, HIPHOP, POP AND REGGAE MUSIC GENRES

# %% [markdown]
# * First of all, let's import every library and our config.py and functions.py files to the notebook.

# %%
# %matplotlib inline
import itertools
import numpy, scipy, matplotlib.pyplot as plt, pandas, librosa,sklearn
import config

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.tree import tree

# %% [markdown]
# * We obtain data from our dataset.

# %%
data_set=pandas.read_csv('ex1.csv',index_col=False)
GENRES=['1', '0']

number_of_rows,number_of_cols = data_set.shape
data_set[:5].style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_a2b8a60a_669e_11e8_9d29_e094679489b9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >4</th>
#         <th class="col_heading level0 col2" >1</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a2b8a60a_669e_11e8_9d29_e094679489b9level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row0_col0" class="data row0 col0" >0</td>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row0_col1" class="data row0 col1" >21</td>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row0_col2" class="data row0 col2" >1</td>
#     </tr>    <tr>
#         <th id="T_a2b8a60a_669e_11e8_9d29_e094679489b9level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row1_col0" class="data row1 col0" >0</td>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row1_col1" class="data row1 col1" >37</td>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row1_col2" class="data row1 col2" >1</td>
#     </tr>    <tr>
#         <th id="T_a2b8a60a_669e_11e8_9d29_e094679489b9level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row2_col0" class="data row2 col0" >0</td>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row2_col1" class="data row2 col1" >14</td>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row2_col2" class="data row2 col2" >1</td>
#     </tr>    <tr>
#         <th id="T_a2b8a60a_669e_11e8_9d29_e094679489b9level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row3_col0" class="data row3 col0" >20</td>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row3_col1" class="data row3 col1" >22</td>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row3_col2" class="data row3 col2" >1</td>
#     </tr>    <tr>
#         <th id="T_a2b8a60a_669e_11e8_9d29_e094679489b9level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row4_col0" class="data row4 col0" >0</td>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row4_col1" class="data row4 col1" >40</td>
#         <td id="T_a2b8a60a_669e_11e8_9d29_e094679489b9row4_col2" class="data row4 col2" >0</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# * Let's split our dataset..
# * Then we seperate both train and test datasets into two part. One for feature columns, one for class column.

# %%
from sklearn.model_selection import train_test_split


data_set_values=numpy.array(data_set)

train, test = train_test_split(data_set_values, test_size = 0.15,random_state=2,
                              stratify=data_set_values[:,number_of_cols-1])

train_x=train[:,:number_of_cols-1]
train_y=train[:,number_of_cols-1]

test_x=test[:,:number_of_cols-1]
test_y=test[:,number_of_cols-1]

print("Training data size: {}".format(train.shape))
print("Test data size: {}".format(test.shape))
# Out:
# Training data size: (14055, 3)
# Test data size: (2481, 3)

# %%
def confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
   
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = numpy.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

def plot_cnf(model,dataset_x,dataset_y,GENRES):
    true_y=dataset_y
    true_x=dataset_x
    pred=model.predict(true_x)

    print("---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------\n")

    print("Real Test dataset labels: \n{}\n".format(true_y))
    print("Predicted Test dataset labels: \n{}".format(pred))

    cnf_matrix=sklearn.metrics.confusion_matrix(true_y,pred)
    plt.figure()
    a=confusion_matrix(cnf_matrix,classes=GENRES,title='Confusion matrix')

# %% [markdown]
# * We use several machine learning algorithms to make classification.
#  - **Algorithms used:**
#    - K-Nearest Neighbor
#    - Random Forest
#    - Support Vector Machine
#    - Neural Network

# %% [markdown]
# * Application of KNN algorithm and its performance analysis

# %%
results_knn=[]
for i in range(1,11):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(train_x,train_y)
    results_knn.append(knn.score(test_x,test_y))
    
max_accuracy_knn=max(results_knn)
best_k=1+results_knn.index(max(results_knn))
print("Max Accuracy is {:.3f} on test dataset with {} neighbors.\n".format(max_accuracy_knn,best_k))

plt.plot(numpy.arange(1,11),results_knn)
plt.xlabel("n Neighbors")
plt.ylabel("Accuracy")


knn=KNeighborsClassifier(n_neighbors=best_k)
knn.fit(train_x,train_y)
print("Training Score: {:.3f}".format(knn.score(train_x,train_y)))
print("Test score: {:.3f}".format(knn.score(test_x,test_y)))  

plot_cnf(knn,test_x,test_y,GENRES)
# Out:
# Max Accuracy is 0.540 on test dataset with 7 neighbors.
#
# Training Score: 0.606
# Test score: 0.540
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# [1 1 0 ... 1 1 1]
#
# Predicted Test dataset labels:
# [1 1 1 ... 1 1 1]

# %% [markdown]
# * Application of Random Forest algorithm and its performance analysis

# %%
results_forest=[]
for i in range(2,20):
    forest=RandomForestClassifier(random_state=42,n_estimators=i)
    forest.fit(train_x,train_y)
    results_forest.append(forest.score(test_x,test_y))
    
max_accuracy_forest=max(results_forest)
best_n_est=2+results_forest.index(max(results_forest))
print("Max Accuracy is {:.3f} on test dataset with {} estimators.\n".format(max_accuracy_forest,best_n_est))

plt.plot(numpy.arange(2,20),results_forest)
plt.xlabel("n Estimators")
plt.ylabel("Accuracy")


forest=RandomForestClassifier(random_state=42,n_estimators=best_n_est)
forest.fit(train_x,train_y)
print("Training Score: {:.3f}".format(forest.score(train_x,train_y)))
print("Test score: {:.3f}".format(forest.score(test_x,test_y)))

plot_cnf(forest,test_x,test_y,GENRES)
# Out:
# Max Accuracy is 0.559 on test dataset with 19 estimators.
#
# Training Score: 0.653
# Test score: 0.559
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# [1 1 0 ... 1 1 1]
#
# Predicted Test dataset labels:
# [1 1 1 ... 1 1 1]

# %% [markdown]
# * Application of SVM algorithm and its performance analysis

# %% [markdown]
# * Application of Neural Network algorithm and its performance analysis

# %%
neural=MLPClassifier(max_iter=4000,random_state=8,hidden_layer_sizes=[80,80])
neural.fit(train_x,train_y)
print("Training Score: {:.3f}".format(neural.score(train_x,train_y)))
print("Test score: {:.3f}".format(neural.score(test_x,test_y)))

plot_cnf(neural,test_x,test_y,GENRES)
# Out:
# Training Score: 0.589
# Test score: 0.593
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# [1 1 0 ... 1 1 1]
#
# Predicted Test dataset labels:
# [1 1 1 ... 1 1 1]

# %%
clf = tree.DecisionTreeClassifier()
clt = clf.fit(train_x,train_y)
print("Training Score: {:.3f}".format(clf.score(train_x,train_y)))
print("Test score: {:.3f}".format(clf.score(test_x,test_y)))
plot_cnf(clf,test_x,test_y,GENRES)
# Out:
# Training Score: 0.655
# Test score: 0.547
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# [1 1 0 ... 1 1 1]
#
# Predicted Test dataset labels:
# [1 1 1 ... 1 1 1]

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(train_x, train_y)
print("Training Score: {:.3f}".format(clf.score(train_x,train_y)))
print("Test score: {:.3f}".format(clf.score(test_x,test_y)))
plot_cnf(clf,test_x,test_y,GENRES)
# Out:
# Training Score: 0.566
# Test score: 0.571
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# [1 1 0 ... 1 1 1]
#
# Predicted Test dataset labels:
# [1 0 1 ... 1 1 1]

# %%
svm=SVC(C=400,gamma=0.001)
svm.fit(train_x,train_y)
print("Training Score: {:.3f}".format(svm.score(train_x,train_y)))
print("Test score: {:.3f}".format(svm.score(test_x,test_y)))

plot_cnf(svm,test_x,test_y,GENRES)
# Out:
# Training Score: 0.591
# Test score: 0.583
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# [1 1 0 ... 1 1 1]
#
# Predicted Test dataset labels:
# [1 1 0 ... 1 1 1]
