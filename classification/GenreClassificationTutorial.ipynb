# %% [markdown]
# ### MULTICLASS CLASSIFICATION FOR METAL, CLASSICAL, BLUES, HIPHOP, POP AND REGGAE MUSIC GENRES

# %% [markdown]
# * First of all, let's import every library and our config.py and functions.py files to the notebook.

# %%
# %matplotlib inline
import itertools
import numpy, scipy, matplotlib.pyplot as plt, pandas, librosa,sklearn
import config

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.tree import tree

# %% [markdown]
# * We obtain data from our dataset.

# %%
data_set=pandas.read_csv('data_set4.csv',index_col=False)
GENRES=['METAL', 'CLASSICAL', 'HIPHOP', 'BLUES', 'POP', 'REGGAE','JAZZ','ROCK','COUNTRY','DISCO']

number_of_rows,number_of_cols = data_set.shape
data_set[:5].style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_d8e88b16_6269_11e8_9608_e094679489b9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >meanZCR</th>
#         <th class="col_heading level0 col1" >stdZCR</th>
#         <th class="col_heading level0 col2" >meanSpecCentroid</th>
#         <th class="col_heading level0 col3" >stdSpecCentroid</th>
#         <th class="col_heading level0 col4" >meanSpecContrast</th>
#         <th class="col_heading level0 col5" >stdSpecContrast</th>
#         <th class="col_heading level0 col6" >meanSpecBandwidth</th>
#         <th class="col_heading level0 col7" >stdSpecBandwidth</th>
#         <th class="col_heading level0 col8" >meanSpecRollof</th>
#         <th class="col_heading level0 col9" >stdSpecRollof</th>
#         <th class="col_heading level0 col10" >meanMFCC_1</th>
#         <th class="col_heading level0 col11" >stdMFCC_1</th>
#         <th class="col_heading level0 col12" >meanMFCC_2</th>
#         <th class="col_heading level0 col13" >stdMFCC_2</th>
#         <th class="col_heading level0 col14" >meanMFCC_3</th>
#         <th class="col_heading level0 col15" >stdMFCC_3</th>
#         <th class="col_heading level0 col16" >meanMFCC_4</th>
#         <th class="col_heading level0 col17" >stdMFCC_4</th>
#         <th class="col_heading level0 col18" >meanMFCC_5</th>
#         <th class="col_heading level0 col19" >stdMFCC_5</th>
#         <th class="col_heading level0 col20" >meanMFCC_6</th>
#         <th class="col_heading level0 col21" >stdMFCC_6</th>
#         <th class="col_heading level0 col22" >meanMFCC_7</th>
#         <th class="col_heading level0 col23" >stdMFCC_7</th>
#         <th class="col_heading level0 col24" >meanMFCC_8</th>
#         <th class="col_heading level0 col25" >stdMFCC_8</th>
#         <th class="col_heading level0 col26" >meanMFCC_9</th>
#         <th class="col_heading level0 col27" >stdMFCC_9</th>
#         <th class="col_heading level0 col28" >meanMFCC_10</th>
#         <th class="col_heading level0 col29" >stdMFCC_10</th>
#         <th class="col_heading level0 col30" >meanMFCC_11</th>
#         <th class="col_heading level0 col31" >stdMFCC_11</th>
#         <th class="col_heading level0 col32" >meanMFCC_12</th>
#         <th class="col_heading level0 col33" >stdMFCC_12</th>
#         <th class="col_heading level0 col34" >meanMFCC_13</th>
#         <th class="col_heading level0 col35" >stdMFCC_13</th>
#         <th class="col_heading level0 col36" >genre</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d8e88b16_6269_11e8_9608_e094679489b9level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col0" class="data row0 col0" >-0.383571</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col1" class="data row0 col1" >-0.557889</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col2" class="data row0 col2" >-0.362719</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col3" class="data row0 col3" >-0.400016</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col4" class="data row0 col4" >-0.465771</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col5" class="data row0 col5" >-0.761076</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col6" class="data row0 col6" >-0.194281</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col7" class="data row0 col7" >-0.300042</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col8" class="data row0 col8" >-0.303462</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col9" class="data row0 col9" >-0.103208</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col10" class="data row0 col10" >0.159989</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col11" class="data row0 col11" >-0.209936</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col12" class="data row0 col12" >-0.178968</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col13" class="data row0 col13" >-0.3674</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col14" class="data row0 col14" >-0.313777</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col15" class="data row0 col15" >-0.634942</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col16" class="data row0 col16" >0.0358685</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col17" class="data row0 col17" >-0.688402</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col18" class="data row0 col18" >-0.138501</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col19" class="data row0 col19" >-0.837277</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col20" class="data row0 col20" >0.214296</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col21" class="data row0 col21" >-0.676084</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col22" class="data row0 col22" >-0.189826</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col23" class="data row0 col23" >-0.396539</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col24" class="data row0 col24" >0.0348717</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col25" class="data row0 col25" >-0.750446</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col26" class="data row0 col26" >-0.488531</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col27" class="data row0 col27" >-0.761094</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col28" class="data row0 col28" >0.0316983</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col29" class="data row0 col29" >-0.83307</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col30" class="data row0 col30" >-0.18042</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col31" class="data row0 col31" >-0.80788</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col32" class="data row0 col32" >0.256188</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col33" class="data row0 col33" >-0.831781</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col34" class="data row0 col34" >-0.179027</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col35" class="data row0 col35" >-0.75792</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row0_col36" class="data row0 col36" >jazz</td>
#     </tr>    <tr>
#         <th id="T_d8e88b16_6269_11e8_9608_e094679489b9level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col0" class="data row1 col0" >-0.719552</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col1" class="data row1 col1" >-0.857447</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col2" class="data row1 col2" >-0.670118</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col3" class="data row1 col3" >-0.553535</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col4" class="data row1 col4" >-0.218842</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col5" class="data row1 col5" >-0.657354</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col6" class="data row1 col6" >-0.384319</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col7" class="data row1 col7" >-0.222323</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col8" class="data row1 col8" >-0.554725</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col9" class="data row1 col9" >-0.161789</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col10" class="data row1 col10" >0.402567</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e094679489b9row1_col11" class="data row1 col11" >-0.0456557</td>
#         <td id="T_d8e88b16_6269_11e8_9608_e09

# %% [markdown]
# * Let's split our dataset..
# * Then we seperate both train and test datasets into two part. One for feature columns, one for class column.

# %%
from sklearn.model_selection import train_test_split


data_set_values=numpy.array(data_set)

train, test = train_test_split(data_set_values, test_size = 0.15,random_state=2,
                              stratify=data_set_values[:,number_of_cols-1])

train_x=train[:,:number_of_cols-1]
train_y=train[:,number_of_cols-1]

test_x=test[:,:number_of_cols-1]
test_y=test[:,number_of_cols-1]

print("Training data size: {}".format(train.shape))
print("Test data size: {}".format(test.shape))
# Out:
# Training data size: (850, 37)
# Test data size: (150, 37)

# %%
def confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
   
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = numpy.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

def plot_cnf(model,dataset_x,dataset_y,GENRES):
    true_y=dataset_y
    true_x=dataset_x
    pred=model.predict(true_x)

    print("---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------\n")

    print("Real Test dataset labels: \n{}\n".format(true_y))
    print("Predicted Test dataset labels: \n{}".format(pred))

    cnf_matrix=sklearn.metrics.confusion_matrix(true_y,pred)
    plt.figure()
    a=confusion_matrix(cnf_matrix,classes=GENRES,title='Confusion matrix')

# %% [markdown]
# * We use several machine learning algorithms to make classification.
#  - **Algorithms used:**
#    - K-Nearest Neighbor
#    - Random Forest
#    - Support Vector Machine
#    - Neural Network

# %% [markdown]
# * Application of KNN algorithm and its performance analysis

# %%
results_knn=[]
for i in range(1,11):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(train_x,train_y)
    results_knn.append(knn.score(test_x,test_y))
    
max_accuracy_knn=max(results_knn)
best_k=1+results_knn.index(max(results_knn))
print("Max Accuracy is {:.3f} on test dataset with {} neighbors.\n".format(max_accuracy_knn,best_k))

plt.plot(numpy.arange(1,11),results_knn)
plt.xlabel("n Neighbors")
plt.ylabel("Accuracy")


knn=KNeighborsClassifier(n_neighbors=best_k)
knn.fit(train_x,train_y)
print("Training Score: {:.3f}".format(knn.score(train_x,train_y)))
print("Test score: {:.3f}".format(knn.score(test_x,test_y)))  

plot_cnf(knn,test_x,test_y,GENRES)
# Out:
# Max Accuracy is 0.580 on test dataset with 9 neighbors.
#
# Training Score: 0.687
# Test score: 0.580
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['hiphop' 'reggae' 'classical' 'blues' 'disco' 'metal' 'pop' 'classical'
#  'blues' 'reggae' 'metal' 'classical' 'reggae' 'metal' 'classical' 'metal'
#  'country' 'pop' 'blues' 'disco' 'country' 'hiphop' 'hiphop' 'pop'
#  'country' 'classical' 'jazz' 'reggae' 'metal' 'country' 'hiphop' 'blues'
#  'disco' 'jazz' 'country' 'country' 'rock' 'pop' 'blues' 'country' 'rock'
#  'disco' 'pop' 'disco' 'country' 'country' 'classical' 'disco' 'pop'
#  'hiphop' 'rock' 'rock' 'metal' 'reggae' 'disco' 'rock' 'metal' 'metal'
#  'jazz' 'pop' 'disco' 'jazz' 'hiphop' 'metal' 'jazz' 'reggae' 'pop'
#  'blues' 'hiphop' 'reggae' 'blues' 'classical' 'pop' 'classical' 'rock'
#  'hiphop' 'classical' 'disco' 'hiphop' 'hiphop' 'pop' 'reggae' 'rock'
#  'disco' 'jazz' 'disco' 'classical' 'blues' 'rock' 'disco' 'jazz' 'reggae'
#  'blues' 'blues' 'metal' 'metal' 'jazz' 'jazz' 'metal' 'rock' 'metal'
#  'pop' 'jazz' 'blues' 'rock' 'reggae' 'country' 'country' 'classical'
#  'rock' 'hiphop' 'jazz' 'reggae' 'blues' 'classical' 'blues' 'metal'
#  'disco' 'country' 'rock' 'pop' 'jazz' 'hiphop' 'reggae' 'hiphop' 'blues'
#  'jazz' 'reggae' 'hiphop' 'country' 'country' 'reggae' 'rock' 'blues'
#  'pop' 'classical' 'pop' 'disco' 'classical' 'hiphop' 'rock' 'reggae'
#  'disco' 'pop' 'jazz' 'classical' 'rock' 'jazz' 'country' 'metal']
#
# Predicted Test dataset labels:
# ['reggae' 'reggae' 'classical' 'blues' 'reggae' 'metal' 'pop' 'classical'
#  'country' 'reggae' 'metal' 'classical' 'reggae' 'metal' 'classical'
#  'metal' 'classical' 'country' 'blues' 'disco' 'country' 'reggae' 'hiphop'
#  'pop' 'pop' 'classical' 'jazz' 'reggae' 'metal' 'classical' 'hiphop'
#  'blues' 'rock' 'blues' 'country' 'country' 'metal' 'country' 'rock'
#  'country' 'reggae' 'country' 'pop' 'disco' 'disco' 'country' 'classical'
#  'disco' 'pop' 'hiphop' 'disco' 'rock' 'disco' 'pop' 'country' 'disco'
#  'metal' 'disco' 'country' 'pop' 'reggae' 'jazz' 'hiphop' 'metal'
#  'classical' 'reggae' 'pop' 'blues' 'reggae' 'hiphop' 'blues' 'country'
#  'reggae' 'classical' 'metal' 'reggae' 'classical' 'disco' 'pop' 'disco'
#  'jazz' 'hiphop' 'metal' 'reggae' 'jazz' 'rock' 'classical' 'blues'
#  'blues' 'jazz' 'jazz' 'disco' 'blues' 'disco' 'metal' 'blues' 'jazz'
#  'jazz' 'country' 'rock' 'metal' 'pop' 'blues' 'blues' 'disco' 'hiphop'
#  'disco' 'disco' 'jazz' 'rock' 'country' 'jazz' 'reggae' 'country'
#  'classical' 'blues' 'metal' 'disco' 'classical' 'rock' 'pop' 'jazz'
#  'hiphop' 'disco' 'hiphop' 'rock' 'classical' 'reggae' 'reggae' 'reggae'
#  'country' 'reggae' 'rock' 'blues' 'pop' 'classical' 'pop' 'disco'
#  'classical' 'disco' 'rock' 'jazz' 'disco' 'country' 'disco' 'classical'
#  'hiphop' 'jazz' 'country' 'metal']

# %% [markdown]
# * Application of Random Forest algorithm and its performance analysis

# %%
results_forest=[]
for i in range(2,20):
    forest=RandomForestClassifier(random_state=42,n_estimators=i)
    forest.fit(train_x,train_y)
    results_forest.append(forest.score(test_x,test_y))
    
max_accuracy_forest=max(results_forest)
best_n_est=2+results_forest.index(max(results_forest))
print("Max Accuracy is {:.3f} on test dataset with {} estimators.\n".format(max_accuracy_forest,best_n_est))

plt.plot(numpy.arange(2,20),results_forest)
plt.xlabel("n Estimators")
plt.ylabel("Accuracy")


forest=RandomForestClassifier(random_state=42,n_estimators=best_n_est)
forest.fit(train_x,train_y)
print("Training Score: {:.3f}".format(forest.score(train_x,train_y)))
print("Test score: {:.3f}".format(forest.score(test_x,test_y)))

plot_cnf(forest,test_x,test_y,GENRES)
# Out:
# Max Accuracy is 0.573 on test dataset with 15 estimators.
#
# Training Score: 0.998
# Test score: 0.573
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['hiphop' 'reggae' 'classical' 'blues' 'disco' 'metal' 'pop' 'classical'
#  'blues' 'reggae' 'metal' 'classical' 'reggae' 'metal' 'classical' 'metal'
#  'country' 'pop' 'blues' 'disco' 'country' 'hiphop' 'hiphop' 'pop'
#  'country' 'classical' 'jazz' 'reggae' 'metal' 'country' 'hiphop' 'blues'
#  'disco' 'jazz' 'country' 'country' 'rock' 'pop' 'blues' 'country' 'rock'
#  'disco' 'pop' 'disco' 'country' 'country' 'classical' 'disco' 'pop'
#  'hiphop' 'rock' 'rock' 'metal' 'reggae' 'disco' 'rock' 'metal' 'metal'
#  'jazz' 'pop' 'disco' 'jazz' 'hiphop' 'metal' 'jazz' 'reggae' 'pop'
#  'blues' 'hiphop' 'reggae' 'blues' 'classical' 'pop' 'classical' 'rock'
#  'hiphop' 'classical' 'disco' 'hiphop' 'hiphop' 'pop' 'reggae' 'rock'
#  'disco' 'jazz' 'disco' 'classical' 'blues' 'rock' 'disco' 'jazz' 'reggae'
#  'blues' 'blues' 'metal' 'metal' 'jazz' 'jazz' 'metal' 'rock' 'metal'
#  'pop' 'jazz' 'blues' 'rock' 'reggae' 'country' 'country' 'classical'
#  'rock' 'hiphop' 'jazz' 'reggae' 'blues' 'classical' 'blues' 'metal'
#  'disco' 'country' 'rock' 'pop' 'jazz' 'hiphop' 'reggae' 'hiphop' 'blues'
#  'jazz' 'reggae' 'hiphop' 'country' 'country' 'reggae' 'rock' 'blues'
#  'pop' 'classical' 'pop' 'disco' 'classical' 'hiphop' 'rock' 'reggae'
#  'disco' 'pop' 'jazz' 'classical' 'rock' 'jazz' 'country' 'metal']
#
# Predicted Test dataset labels:
# ['hiphop' 'reggae' 'classical' 'blues' 'reggae' 'disco' 'pop' 'classical'
#  'blues' 'rock' 'metal' 'classical' 'reggae' 'metal' 'classical' 'metal'
#  'country' 'reggae' 'blues' 'disco' 'country' 'hiphop' 'hiphop' 'pop'
#  'pop' 'classical' 'jazz' 'reggae' 'metal' 'jazz' 'hiphop' 'rock' 'rock'
#  'blues' 'country' 'country' 'rock' 'rock' 'blues' 'hiphop' 'reggae'
#  'metal' 'pop' 'disco' 'country' 'country' 'classical' 'hiphop' 'pop'
#  'hiphop' 'blues' 'disco' 'disco' 'pop' 'blues' 'country' 'country'
#  'metal' 'jazz' 'pop' 'hiphop' 'jazz' 'hiphop' 'metal' 'jazz' 'reggae'
#  'pop' 'country' 'reggae' 'pop' 'blues' 'country' 'reggae' 'classical'
#  'rock' 'reggae' 'classical' 'reggae' 'hiphop' 'blues' 'country' 'reggae'
#  'metal' 'reggae' 'rock' 'disco' 'classical' 'jazz' 'disco' 'country'
#  'jazz' 'disco' 'blues' 'hiphop' 'metal' 'metal' 'jazz' 'classical' 'jazz'
#  'reggae' 'metal' 'pop' 'jazz' 'blues' 'jazz' 'hiphop' 'country' 'reggae'
#  'disco' 'disco' 'blues' 'jazz' 'blues' 'blues' 'reggae' 'blues' 'metal'
#  'disco' 'classical' 'reggae' 'pop' 'classical' 'hiphop' 'reggae' 'hiphop'
#  'blues' 'classical' 'reggae' 'disco' 'reggae' 'country' 'reggae' 'hiphop'
#  'rock' 'pop' 'classical' 'pop' 'disco' 'classical' 'disco' 'rock' 'blues'
#  'disco' 'hiphop' 'disco' 'classical' 'reggae' 'jazz' 'country' 'blues']

# %% [markdown]
# * Application of SVM algorithm and its performance analysis

# %%
svm=SVC(C=1000,gamma=0.001)
svm.fit(train_x,train_y)
print("Training Score: {:.3f}".format(svm.score(train_x,train_y)))
print("Test score: {:.3f}".format(svm.score(test_x,test_y)))

plot_cnf(svm,test_x,test_y,GENRES)
# Out:
# Training Score: 0.791
# Test score: 0.627
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['hiphop' 'reggae' 'classical' 'blues' 'disco' 'metal' 'pop' 'classical'
#  'blues' 'reggae' 'metal' 'classical' 'reggae' 'metal' 'classical' 'metal'
#  'country' 'pop' 'blues' 'disco' 'country' 'hiphop' 'hiphop' 'pop'
#  'country' 'classical' 'jazz' 'reggae' 'metal' 'country' 'hiphop' 'blues'
#  'disco' 'jazz' 'country' 'country' 'rock' 'pop' 'blues' 'country' 'rock'
#  'disco' 'pop' 'disco' 'country' 'country' 'classical' 'disco' 'pop'
#  'hiphop' 'rock' 'rock' 'metal' 'reggae' 'disco' 'rock' 'metal' 'metal'
#  'jazz' 'pop' 'disco' 'jazz' 'hiphop' 'metal' 'jazz' 'reggae' 'pop'
#  'blues' 'hiphop' 'reggae' 'blues' 'classical' 'pop' 'classical' 'rock'
#  'hiphop' 'classical' 'disco' 'hiphop' 'hiphop' 'pop' 'reggae' 'rock'
#  'disco' 'jazz' 'disco' 'classical' 'blues' 'rock' 'disco' 'jazz' 'reggae'
#  'blues' 'blues' 'metal' 'metal' 'jazz' 'jazz' 'metal' 'rock' 'metal'
#  'pop' 'jazz' 'blues' 'rock' 'reggae' 'country' 'country' 'classical'
#  'rock' 'hiphop' 'jazz' 'reggae' 'blues' 'classical' 'blues' 'metal'
#  'disco' 'country' 'rock' 'pop' 'jazz' 'hiphop' 'reggae' 'hiphop' 'blues'
#  'jazz' 'reggae' 'hiphop' 'country' 'country' 'reggae' 'rock' 'blues'
#  'pop' 'classical' 'pop' 'disco' 'classical' 'hiphop' 'rock' 'reggae'
#  'disco' 'pop' 'jazz' 'classical' 'rock' 'jazz' 'country' 'metal']
#
# Predicted Test dataset labels:
# ['hiphop' 'reggae' 'classical' 'blues' 'reggae' 'metal' 'pop' 'classical'
#  'jazz' 'disco' 'metal' 'classical' 'reggae' 'blues' 'classical' 'metal'
#  'classical' 'rock' 'blues' 'disco' 'country' 'hiphop' 'hiphop' 'pop'
#  'pop' 'classical' 'jazz' 'reggae' 'metal' 'classical' 'hiphop' 'blues'
#  'blues' 'country' 'country' 'country' 'rock' 'country' 'blues' 'country'
#  'blues' 'rock' 'pop' 'disco' 'reggae' 'country' 'classical' 'disco' 'pop'
#  'hiphop' 'disco' 'rock' 'disco' 'hiphop' 'country' 'rock' 'metal' 'metal'
#  'jazz' 'pop' 'reggae' 'jazz' 'disco' 'metal' 'classical' 'reggae' 'pop'
#  'blues' 'hiphop' 'pop' 'blues' 'country' 'reggae' 'classical' 'rock'
#  'hiphop' 'classical' 'blues' 'hiphop' 'disco' 'pop' 'reggae' 'metal'
#  'reggae' 'jazz' 'rock' 'classical' 'classical' 'disco' 'jazz' 'jazz'
#  'reggae' 'blues' 'disco' 'metal' 'metal' 'jazz' 'jazz' 'metal' 'country'
#  'metal' 'pop' 'blues' 'blues' 'disco' 'hiphop' 'pop' 'rock' 'disco'
#  'disco' 'blues' 'jazz' 'reggae' 'blues' 'classical' 'blues' 'metal'
#  'disco' 'blues' 'reggae' 'pop' 'classical' 'hiphop' 'reggae' 'reggae'
#  'disco' 'classical' 'reggae' 'hiphop' 'rock' 'country' 'blues' 'hiphop'
#  'blues' 'pop' 'classical' 'pop' 'disco' 'classical' 'hiphop' 'rock'
#  'jazz' 'rock' 'country' 'rock' 'classical' 'reggae' 'jazz' 'country'
#  'metal']

# %% [markdown]
# * Application of Neural Network algorithm and its performance analysis

# %%
neural=MLPClassifier(max_iter=2000,random_state=8,hidden_layer_sizes=[40,40])
neural.fit(train_x,train_y)
print("Training Score: {:.3f}".format(neural.score(train_x,train_y)))
print("Test score: {:.3f}".format(neural.score(test_x,test_y)))

plot_cnf(neural,test_x,test_y,GENRES)
# Out:
# Training Score: 0.814
# Test score: 0.667
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['hiphop' 'reggae' 'classical' 'blues' 'disco' 'metal' 'pop' 'classical'
#  'blues' 'reggae' 'metal' 'classical' 'reggae' 'metal' 'classical' 'metal'
#  'country' 'pop' 'blues' 'disco' 'country' 'hiphop' 'hiphop' 'pop'
#  'country' 'classical' 'jazz' 'reggae' 'metal' 'country' 'hiphop' 'blues'
#  'disco' 'jazz' 'country' 'country' 'rock' 'pop' 'blues' 'country' 'rock'
#  'disco' 'pop' 'disco' 'country' 'country' 'classical' 'disco' 'pop'
#  'hiphop' 'rock' 'rock' 'metal' 'reggae' 'disco' 'rock' 'metal' 'metal'
#  'jazz' 'pop' 'disco' 'jazz' 'hiphop' 'metal' 'jazz' 'reggae' 'pop'
#  'blues' 'hiphop' 'reggae' 'blues' 'classical' 'pop' 'classical' 'rock'
#  'hiphop' 'classical' 'disco' 'hiphop' 'hiphop' 'pop' 'reggae' 'rock'
#  'disco' 'jazz' 'disco' 'classical' 'blues' 'rock' 'disco' 'jazz' 'reggae'
#  'blues' 'blues' 'metal' 'metal' 'jazz' 'jazz' 'metal' 'rock' 'metal'
#  'pop' 'jazz' 'blues' 'rock' 'reggae' 'country' 'country' 'classical'
#  'rock' 'hiphop' 'jazz' 'reggae' 'blues' 'classical' 'blues' 'metal'
#  'disco' 'country' 'rock' 'pop' 'jazz' 'hiphop' 'reggae' 'hiphop' 'blues'
#  'jazz' 'reggae' 'hiphop' 'country' 'country' 'reggae' 'rock' 'blues'
#  'pop' 'classical' 'pop' 'disco' 'classical' 'hiphop' 'rock' 'reggae'
#  'disco' 'pop' 'jazz' 'classical' 'rock' 'jazz' 'country' 'metal']
#
# Predicted Test dataset labels:
# ['hiphop' 'reggae' 'classical' 'blues' 'reggae' 'metal' 'pop' 'classical'
#  'jazz' 'disco' 'metal' 'classical' 'reggae' 'jazz' 'classical' 'metal'
#  'country' 'rock' 'blues' 'disco' 'country' 'hiphop' 'hiphop' 'pop' 'pop'
#  'classical' 'jazz' 'reggae' 'metal' 'country' 'hiphop' 'blues' 'rock'
#  'blues' 'country' 'country' 'rock' 'country' 'blues' 'country' 'reggae'
#  'metal' 'pop' 'disco' 'disco' 'country' 'classical' 'disco' 'disco'
#  'hiphop' 'disco' 'rock' 'disco' 'hiphop' 'country' 'jazz' 'metal' 'metal'
#  'jazz' 'pop' 'reggae' 'jazz' 'hiphop' 'metal' 'jazz' 'reggae' 'pop'
#  'blues' 'blues' 'pop' 'blues' 'country' 'reggae' 'classical' 'rock'
#  'disco' 'classical' 'blues' 'hiphop' 'hiphop' 'pop' 'reggae' 'metal'
#  'reggae' 'jazz' 'rock' 'classical' 'classical' 'hiphop' 'jazz' 'jazz'
#  'reggae' 'blues' 'disco' 'metal' 'hiphop' 'jazz' 'jazz' 'metal' 'country'
#  'metal' 'pop' 'blues' 'blues' 'rock' 'reggae' 'jazz' 'country' 'disco'
#  'disco' 'blues' 'jazz' 'reggae' 'blues' 'classical' 'blues' 'metal'
#  'disco' 'blues' 'country' 'pop' 'classical' 'hiphop' 'reggae' 'hiphop'
#  'rock' 'classical' 'reggae' 'hiphop' 'rock' 'country' 'blues' 'hiphop'
#  'blues' 'pop' 'classical' 'pop' 'disco' 'classical' 'hiphop' 'rock'
#  'rock' 'disco' 'pop' 'rock' 'classical' 'hiphop' 'jazz' 'country' 'metal']

# %%
clf = tree.DecisionTreeClassifier()
clt = clf.fit(train_x,train_y)
print("Training Score: {:.3f}".format(clf.score(train_x,train_y)))
print("Test score: {:.3f}".format(clf.score(test_x,test_y)))
plot_cnf(clf,test_x,test_y,GENRES)
# Out:
# Training Score: 1.000
# Test score: 0.467
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['hiphop' 'reggae' 'classical' 'blues' 'disco' 'metal' 'pop' 'classical'
#  'blues' 'reggae' 'metal' 'classical' 'reggae' 'metal' 'classical' 'metal'
#  'country' 'pop' 'blues' 'disco' 'country' 'hiphop' 'hiphop' 'pop'
#  'country' 'classical' 'jazz' 'reggae' 'metal' 'country' 'hiphop' 'blues'
#  'disco' 'jazz' 'country' 'country' 'rock' 'pop' 'blues' 'country' 'rock'
#  'disco' 'pop' 'disco' 'country' 'country' 'classical' 'disco' 'pop'
#  'hiphop' 'rock' 'rock' 'metal' 'reggae' 'disco' 'rock' 'metal' 'metal'
#  'jazz' 'pop' 'disco' 'jazz' 'hiphop' 'metal' 'jazz' 'reggae' 'pop'
#  'blues' 'hiphop' 'reggae' 'blues' 'classical' 'pop' 'classical' 'rock'
#  'hiphop' 'classical' 'disco' 'hiphop' 'hiphop' 'pop' 'reggae' 'rock'
#  'disco' 'jazz' 'disco' 'classical' 'blues' 'rock' 'disco' 'jazz' 'reggae'
#  'blues' 'blues' 'metal' 'metal' 'jazz' 'jazz' 'metal' 'rock' 'metal'
#  'pop' 'jazz' 'blues' 'rock' 'reggae' 'country' 'country' 'classical'
#  'rock' 'hiphop' 'jazz' 'reggae' 'blues' 'classical' 'blues' 'metal'
#  'disco' 'country' 'rock' 'pop' 'jazz' 'hiphop' 'reggae' 'hiphop' 'blues'
#  'jazz' 'reggae' 'hiphop' 'country' 'country' 'reggae' 'rock' 'blues'
#  'pop' 'classical' 'pop' 'disco' 'classical' 'hiphop' 'rock' 'reggae'
#  'disco' 'pop' 'jazz' 'classical' 'rock' 'jazz' 'country' 'metal']
#
# Predicted Test dataset labels:
# ['metal' 'reggae' 'classical' 'blues' 'reggae' 'disco' 'reggae' 'country'
#  'country' 'rock' 'metal' 'classical' 'reggae' 'metal' 'classical' 'rock'
#  'classical' 'country' 'blues' 'disco' 'jazz' 'hiphop' 'hiphop' 'reggae'
#  'pop' 'classical' 'disco' 'reggae' 'metal' 'disco' 'hiphop' 'blues'
#  'country' 'country' 'country' 'country' 'blues' 'country' 'disco' 'rock'
#  'reggae' 'rock' 'pop' 'disco' 'rock' 'pop' 'classical' 'hiphop' 'country'
#  'hiphop' 'rock' 'metal' 'disco' 'pop' 'classical' 'hiphop' 'blues'
#  'metal' 'jazz' 'pop' 'reggae' 'country' 'hiphop' 'metal' 'jazz' 'reggae'
#  'pop' 'blues' 'rock' 'hiphop' 'blues' 'jazz' 'disco' 'classical' 'rock'
#  'hiphop' 'country' 'rock' 'hiphop' 'disco' 'jazz' 'reggae' 'metal'
#  'country' 'rock' 'disco' 'classical' 'country' 'disco' 'jazz' 'country'
#  'jazz' 'classical' 'hiphop' 'disco' 'hiphop' 'jazz' 'jazz' 'disco'
#  'reggae' 'metal' 'pop' 'jazz' 'blues' 'rock' 'hiphop' 'country' 'rock'
#  'disco' 'rock' 'hiphop' 'jazz' 'reggae' 'country' 'reggae' 'blues'
#  'metal' 'disco' 'country' 'reggae' 'pop' 'classical' 'country' 'reggae'
#  'hiphop' 'hiphop' 'classical' 'reggae' 'reggae' 'reggae' 'country'
#  'blues' 'blues' 'blues' 'pop' 'classical' 'pop' 'pop' 'classical' 'disco'
#  'blues' 'rock' 'hiphop' 'disco' 'rock' 'classical' 'reggae' 'jazz'
#  'country' 'hiphop']

# %%
from sklearn.naive_bayes import BernoulliNB
clf = BernoulliNB()
clf.fit(train_x, train_y)
print("Training Score: {:.3f}".format(clf.score(train_x,train_y)))
print("Test score: {:.3f}".format(clf.score(test_x,test_y)))
plot_cnf(clf,test_x,test_y,GENRES)
# Out:
# Training Score: 0.380
# Test score: 0.427
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['hiphop' 'reggae' 'classical' 'blues' 'disco' 'metal' 'pop' 'classical'
#  'blues' 'reggae' 'metal' 'classical' 'reggae' 'metal' 'classical' 'metal'
#  'country' 'pop' 'blues' 'disco' 'country' 'hiphop' 'hiphop' 'pop'
#  'country' 'classical' 'jazz' 'reggae' 'metal' 'country' 'hiphop' 'blues'
#  'disco' 'jazz' 'country' 'country' 'rock' 'pop' 'blues' 'country' 'rock'
#  'disco' 'pop' 'disco' 'country' 'country' 'classical' 'disco' 'pop'
#  'hiphop' 'rock' 'rock' 'metal' 'reggae' 'disco' 'rock' 'metal' 'metal'
#  'jazz' 'pop' 'disco' 'jazz' 'hiphop' 'metal' 'jazz' 'reggae' 'pop'
#  'blues' 'hiphop' 'reggae' 'blues' 'classical' 'pop' 'classical' 'rock'
#  'hiphop' 'classical' 'disco' 'hiphop' 'hiphop' 'pop' 'reggae' 'rock'
#  'disco' 'jazz' 'disco' 'classical' 'blues' 'rock' 'disco' 'jazz' 'reggae'
#  'blues' 'blues' 'metal' 'metal' 'jazz' 'jazz' 'metal' 'rock' 'metal'
#  'pop' 'jazz' 'blues' 'rock' 'reggae' 'country' 'country' 'classical'
#  'rock' 'hiphop' 'jazz' 'reggae' 'blues' 'classical' 'blues' 'metal'
#  'disco' 'country' 'rock' 'pop' 'jazz' 'hiphop' 'reggae' 'hiphop' 'blues'
#  'jazz' 'reggae' 'hiphop' 'country' 'country' 'reggae' 'rock' 'blues'
#  'pop' 'classical' 'pop' 'disco' 'classical' 'hiphop' 'rock' 'reggae'
#  'disco' 'pop' 'jazz' 'classical' 'rock' 'jazz' 'country' 'metal']
#
# Predicted Test dataset labels:
# ['reggae' 'hiphop' 'classical' 'blues' 'blues' 'metal' 'pop' 'classical'
#  'blues' 'blues' 'metal' 'classical' 'reggae' 'metal' 'classical' 'metal'
#  'classical' 'pop' 'blues' 'pop' 'country' 'reggae' 'pop' 'pop' 'pop'
#  'classical' 'blues' 'pop' 'metal' 'classical' 'metal' 'metal' 'blues'
#  'country' 'country' 'blues' 'metal' 'pop' 'metal' 'metal' 'reggae'
#  'metal' 'pop' 'metal' 'jazz' 'pop' 'classical' 'disco' 'pop' 'metal'
#  'metal' 'metal' 'metal' 'pop' 'disco' 'pop' 'metal' 'metal' 'jazz' 'pop'
#  'rock' 'pop' 'metal' 'metal' 'classical' 'reggae' 'pop' 'blues' 'reggae'
#  'pop' 'rock' 'blues' 'reggae' 'classical' 'metal' 'pop' 'classical'
#  'blues' 'pop' 'disco' 'pop' 'reggae' 'metal' 'pop' 'jazz' 'pop'
#  'classical' 'jazz' 'metal' 'disco' 'blues' 'pop' 'jazz' 'metal' 'metal'
#  'metal' 'blues' 'classical' 'rock' 'blues' 'metal' 'pop' 'classical'
#  'jazz' 'pop' 'pop' 'pop' 'blues' 'classical' 'metal' 'metal' 'blues'
#  'reggae' 'blues' 'classical' 'blues' 'metal' 'pop' 'country' 'blues'
#  'pop' 'jazz' 'pop' 'jazz' 'jazz' 'metal' 'classical' 'reggae' 'hiphop'
#  'reggae' 'classical' 'blues' 'metal' 'metal' 'pop' 'classical' 'pop'
#  'pop' 'classical' 'metal' 'blues' 'jazz' 'disco' 'pop' 'metal'
#  'classical' 'reggae' 'blues' 'classical' 'metal']
